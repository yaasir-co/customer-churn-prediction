# %% [markdown]
# # Customer Churn ML Masterclass
# End-to-end notebook for exploration and interview preparation.

# %%
import pandas as pd
df = pd.read_csv('../data/customer_churn.csv')
df.head()

# %%
df.info()
df['churn'].value_counts(normalize=True)

# %% [markdown]
# ## Key question
# What patterns distinguish customers who churn from customers who stay?

# %%
df.groupby('contract_type')['churn'].mean().sort_values(ascending=False)

# %% [markdown]
# Continue by reproducing the preprocessing and model comparison in `train_models.py`.
